# %% [markdown]
# # Подгрузка библиотек

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import os
import numpy as np
import pandas as pd
from collections import Counter
import re

import seaborn as sns
from matplotlib import pyplot as plt
from tqdm import tqdm

import warnings

warnings.filterwarnings('ignore')

# %%
df_path = './data/'

# %%
tqdm.pandas(desc="Processing rows...", ncols=100)

# %% [markdown]
# # 1. Загрузка данных

# %% [markdown]
# Исходный набор представляет собой открытые данные [Государственного каталога музейного фонда РФ Министерства культуры РФ](https://opendata.mkrf.ru/opendata/7705851331-museum-exhibits)

# %%
# Подгрузка данных
data = pd.read_csv(f'{df_path}/Russian_museum.csv', sep=';', encoding='utf-8')
data.head()
# Out:
#                                Наименование предмета  \
# 0                                Декоративный мотив.
# 1  Женский портрет в шляпе с пером. На обороте: Н...
# 2                  Декоративные мотивы. Три виньетки
# 3                              Два женских портрета.
# 4                       Женский портрет (погрудный).
#
#                                          Автор  \
# 0    ["Малевич Казимир Северинович 1879-1935"]
# 1  ["Малевич Казимир Северинович (1879-1935)"]
# 2  ["Малевич Казимир Северинович (1879-1935)"]
# 3    ["Малевич Казимир Северинович 1879-1935"]
# 4  ["Малевич Казимир Северинович (1879-1935)"]
#
#                                                Музей  \
# 0  Федеральное государственное бюджетное учрежден...
# 1  Федеральное государственное бюджетное учрежден...
# 2  Федеральное государственное бюджетное учрежден...
# 3  Федеральное государственное бюджетное учрежден...
# 4  Федеральное государственное бюджетное учрежден...
#
#                                                Items  \
# 0                                   ["бумага, тушь"]
# 1         ["бумага, графитный карандаш, растушевка"]
# 2                       ["бумага верже, тушь, перо"]
# 3                         ["бумага, черные чернила"]
# 4  ["бумага, бумага цветная, тушь, гуашь, наклейка"]
#
#   Дата создания предмета (строка) Место создания  \
# 0                            1908            NaN
# 1                    Конец 1900-х            NaN
# 2                    Ок. 1908 (?)            NaN
# 3    Конец 1920-х - начало 1930-х            NaN
# 4   Сер.-2-ая половина 1900-х (?)            NaN
#
#                          Строковое описание размеров  \
# 0                         Л.: 9 x 3,8  И.: 6,2 x 2,3
# 1                         Л.: 18,5 x 16  И.: 12 x 12
# 2  13,6 x 15,7  И.1: 11,5 х 9,7  И.2: 5,8 х 2,5  ...
# 3         20,7 x 13,7. (И.1: 7,8х7,8;  И.2: 7,6х7,1)
# 4                    Л.: 15,9 x 15,7;  И.: 7,7 x 7,7
#
#                                             Описание  Количество составляющих  \
# 0  В вертикальной прямоугольной рамке декоративны...                      1.0
# 1  Портрет женщины в шляпе с пером (фронтально, о...                      1.0
# 2  Три виньетки. Слева: овальная виньетка с цвето...                      1.0
# 3  Один под другим, в рамках: два женских портрет...                      1.0
# 4  В круге:  на фоне с цветочными узорами - поясн...                      1.0
#
#                                          Изображение  ...  Длина  \
# 0  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 1  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 2  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 3  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 4  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
#
#   Единица измерения размера Интервал времени создания предмета (начало)  \
# 0                       NaN                    1908-01-01T12:00:00.000Z
# 1                       NaN                    1906-01-01T12:00:00.000Z
# 2                       NaN                    1908-01-01T12:00:00.000Z
# 3                       NaN                    1926-01-01T12:00:00.000Z
# 4                       NaN                    1903-01-01T12:00:00.000Z
#
#   Интервал времени создания предмета (окончание)  \
# 0                                            NaN
# 1                       1909-01-01T12:00:00.000Z
# 2                                            NaN
# 3                       1933-01-01T12:00:00.000Z
# 4                       1909-01-01T12:00:00.000Z
#
#    Точность задания времени (день, месяц, год, век, эпоха).  \
# 0                                               YEAR
# 1                                               YEAR
# 2                                               YEAR
# 3                                               YEAR
# 4                                               YEAR
#
#    URL предмета на сайте музея  Ключевые слова  \
# 0                          NaN             NaN
# 1                          NaN             NaN
# 2                          NaN             NaN
# 3                          NaN             NaN
# 4                          NaN             NaN
#
#   Краткое описание истории бытования (провенанс) предмета  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Идентификатор статуса предмета Типология
# 0                              6   графика
# 1                              6   графика
# 2                              6   графика
# 3                              6   графика
# 4                              6   графика
#
# [5 rows x 26 columns]

# %% [markdown]
# # 2. Очистка данных

# %%
# Удаление дубликатов
data_cleaned = data.drop_duplicates()

# Сброс индексов после удаления дубликатов
data_cleaned = data_cleaned.reset_index(drop=True)

# %%
data_cleaned
# Out:
#                                    Наименование предмета  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 57249                  Портрет Анны Андреевны Ахматовой.
# 57250                                              Зима.
# 57251                       Лестница. Ленинский проспект
# 57252                                       Без названия
# 57253                                            Завтрак
#
#                                                 Автор  \
# 0           ["Малевич Казимир Северинович 1879-1935"]
# 1         ["Малевич Казимир Северинович (1879-1935)"]
# 2         ["Малевич Казимир Северинович (1879-1935)"]
# 3           ["Малевич Казимир Северинович 1879-1935"]
# 4         ["Малевич Казимир Северинович (1879-1935)"]
# ...                                               ...
# 57249  ["Петров-Водкин Кузьма Сергеевич (1878-1939)"]
# 57250          ["Павлов Семен Андреевич 1893 - 1941"]
# 57251          ["Волков Владимир Петрович 1923-1987"]
# 57252   ["Добротворский Сергей Николаевич 1959-1997"]
# 57253           ["Белютин Элий Михайлович род. 1925"]
#
#                                                    Музей  \
# 0      Федеральное государственное бюджетное учрежден...
# 1      Федеральное государственное бюджетное учрежден...
# 2      Федеральное государственное бюджетное учрежден...
# 3      Федеральное государственное бюджетное учрежден...
# 4      Федеральное государственное бюджетное учрежден...
# ...                                                  ...
# 57249  Федеральное государственное бюджетное учрежден...
# 57250  Федеральное государственное бюджетное учрежден...
# 57251  Федеральное государственное бюджетное учрежден...
# 57252  Федеральное государственное бюджетное учрежден...
# 57253  Федеральное государственное бюджетное учрежден...
#
#                                                    Items  \
# 0                                       ["бумага, тушь"]
# 1             ["бумага, графитный карандаш, растушевка"]
# 2                           ["бумага верже, тушь, перо"]
# 3                             ["бумага, черные чернила"]
# 4      ["бумага, бумага цветная, тушь, гуашь, наклейка"]
# ...                                                  ...
# 57249                                   ["холст, масло"]
# 57250                                   ["холст, масло"]
# 57251                                   ["холст, масло"]
# 57252                         ["холст на фанере, масло"]
# 57253                                   ["холст, масло"]
#
#       Дата создания предмета (строка) Место создания  \
# 0                                1908            NaN
# 1                        Конец 1900-х            NaN
# 2                        Ок. 1908 (?)            NaN
# 3        Конец 1920-х - начало 1930-х            NaN
# 4       Сер.-2-ая половина 1900-х (?)            NaN
# ...                               ...            ...
# 57249                            1922            NaN
# 57250                            1923            NaN
# 57251                            1987            NaN
# 57252                Конец 1980-х гг.            NaN
# 57253                            1999            NaN
#
#                              Строковое описание размеров  \
# 0                             Л.: 9 x 3,8  И.: 6,2 x 2,3
# 1                             Л.: 18,5 x 16  И.: 12 x 12
# 2      13,6 x 15,7  И.1: 11,5 х 9,7  И.2: 5,8 х 2,5  ...
# 3             20,7 x 13,7. (И.1: 7,8х7,8;  И.2: 7,6х7,1)
# 4                        Л.: 15,9 x 15,7;  И.: 7,7 x 7,7
# ...                                                  ...
# 57249                                          54,5x43,5
# 57250                                           79 x 114
# 57251                                           100 x 65
# 57252                                        57,7 х 40,2
# 57253                                          200 x 265
#
#                                                 Описание  \
# 0      В вертикальной прямоугольной рамке декоративны...
# 1      Портрет женщины в шляпе с пером (фронтально, о...
# 2      Три виньетки. Слева: овальная виньетка с цвето...
# 3      Один под другим, в рамках: два женских портрет...
# 4      В круге:  на фоне с цветочными узорами - поясн...
# ...                                                  ...
# 57249  Ахматова изображена по плечи, с поворотом слег...
# 57250  Городской пейзаж. На первом плане: справа руин...
# 57251  Абстрактная композиция состоящая из прямоуголь...
# 57252  В верхней части картины - летящий  влево желты...
# 57253  Абстрактно-предметная композиция. В центре изо...
#
#        Количество составляющих  \
# 0                          1.0
# 1                          1.0
# 2                          1.0
# 3                          1.0
# 4                          1.0
# ...                        ...
# 57249                      1.0
# 57250                      1.0
# 57251                      1.0
# 57252                      1.0
# 57253                      1.0
#
#                                              Изображение  ...  Длина  \
# 0      [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 1      [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 2      [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 3      [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 4      [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# ...                                                  ...  ...    ...
# 57249  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 57250  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 57251  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 57252  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
# 57253  [{"url":"http://goskatalog.ru/muzfo-imaginator...  ...    NaN
#
#       Единица измерения размера Интервал времени создания предмета (начало)  \
# 0                           NaN                    1908-01-01T12:00:00.000Z
# 1                           NaN                    1906-01-01T12:00:00.000Z
# 2                           NaN                    1908-01-01T12:00:00.000Z
# 3                           NaN                    1926-01-01T12:00:00.000Z
# 4                           NaN                    1903-01-01T12:00:00.000Z
# ...                         ...                                         ...
# 57249                       NaN                    1922-01-01T12:00:00.000Z
# 57250                       NaN                    1923-01-01T12:00:00.000Z
# 57251                       NaN                    1987-01-01T12:00:00.000Z
# 57252                       NaN                    1985-01-01T12:00:00.000Z
# 57253                       NaN                    1999-01-01T12:00:00.000Z
#
#       Интервал времени создания предмета (окончание)  \
# 0                                                NaN
# 1                           1909-01-01T12:00:00.000Z
# 2                                                NaN
# 3                           1933-01-01T12:00:00.000Z
# 4                           1909-01-01T12:00:00.000Z
# ...                                              ...
# 57249                                            NaN
# 57250                                            NaN
# 57251                                            NaN
# 57252                       1990-01-01T12:00:00.000Z
# 57253                                            NaN
#
#        Точность задания времени (день, месяц, год, век, эпоха).  \
# 0                                                   YEAR
# 1                                                   YEAR
# 2                                                   YEAR
# 3                                                   YEAR
# 4                                                   YEAR
# ...                                                  ...
# 57249                                               YEAR
# 57250                                               YEAR
# 57251                                               YEAR
# 57252                                               YEAR
# 57253                                               YEAR
#
#                              URL предмета на сайте музея  Ключевые слова  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3                                                    NaN             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 57249  https://rusmuseumvrm.ru/data/collections/paint...             NaN
# 57250                                                NaN             NaN
# 57251                                                NaN             NaN
# 57252                                                NaN             NaN
# 57253                                                NaN             NaN
#
#       Краткое описание истории бытования (провенанс) предмета  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 57249                                                NaN
# 57250                                                NaN
# 57251                                                NaN
# 57252                                                NaN
# 57253                                                NaN
#
#       Идентификатор статуса предмета Типология
# 0                                  6   графика
# 1                                  6   графика
# 2                                  6   графика
# 3                                  6   графика
# 4                                  6   графика
# ...                              ...       ...
# 57249                              6  живопись
# 57250                              6  живопись
# 57251                              6  живопись
# 57252                              6  живопись
# 57253                              6  живопись
#
# [57254 rows x 26 columns]

# %%
def get_graph(top_5, column):
    plt.figure(figsize=(8, 6))
    sns.barplot(x=top_5.index, y=top_5.values, palette='viridis')
    plt.title(f'Top 5 Frequent Values in {column}')
    plt.xlabel('Category')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.show()

# %%
 for column in data_cleaned.columns:
    print(column)
    if data[column].dtype == 'object' or data[column].dtype.name == 'category':
        # Получаем топ-5 частых значений для каждого категориального признака
        top_5 = data_cleaned[column].value_counts().head(5)
        get_graph(top_5, column)
# Out:
# Наименование предмета
# Автор
# Музей
# Items
# Дата создания предмета (строка)
# Место создания
# Строковое описание размеров
# Описание
# Количество составляющих
# Изображение
# Регистрационный номер Госкаталога
# Дата регистрации записи.
# Инвентарный номер
# Номер по ГИК
# Ширина
# Высота
# Длина
# Единица измерения размера
# Интервал времени создания предмета (начало)
# Интервал времени создания предмета (окончание)
# Точность задания времени (день, месяц, год, век, эпоха).
# URL предмета на сайте музея
# Ключевые слова
# Краткое описание истории бытования (провенанс) предмета
# Идентификатор статуса предмета
# Типология

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57254 entries, 0 to 57253
# Data columns (total 26 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Наименование предмета                                     57254 non-null  object
#  1   Автор                                                     44004 non-null  object
#  2   Музей                                                     57254 non-null  object
#  3   Items                                                     54817 non-null  object
#  4   Дата создания предмета (строка)                           55223 non-null  object
#  5   Место создания                                            6178 non-null   object
#  6   Строковое описание размеров                               57248 non-null  object
#  7   Описание                                                  57254 non-null  object
#  8   Количество составляющих                                   57254 non-null  float64
#  9   Изображение                                               53170 non-null  object
#  10  Регистрационный номер Госкаталога                         57254 non-null  float64
#  11  Дата регистрации записи.                                  57254 non-null  object
#  12  Инвентарный номер                                         57252 non-null  object
#  13  Номер по ГИК                                              56349 non-null  object
#  14  Ширина                                                    4348 non-null   float64
#  15  Высота                                                    2229 non-null   float64
#  16  Длина                                                     4349 non-null   float64
#  17  Единица измерения размера                                 7956 non-null   object
#  18  Интервал времени создания предмета (начало)               54796 non-null  object
#  19  Интервал времени создания предмета (окончание)            18865 non-null  object
#  20  Точность задания времени (день, месяц, год, век, эпоха).  57254 non-null  object
#  21  URL предмета на сайте музея                               764 non-null    object
#  22  Ключевые слова                                            0 non-null      float64
#  23  Краткое описание истории бытования (провенанс) предмета   0 non-null      float64
#  24  Идентификатор статуса предмета                            57254 non-null  int64
#  25  Типология                                                 57254 non-null  object
# dtypes: float64(7), int64(1), object(18)
# memory usage: 11.4+ MB

# %%
# Исключаем неинформативные признаки
cols_for_drop = ['Музей', 'Строковое описание размеров', 'Количество составляющих', 'Инвентарный номер', 'Номер по ГИК',
                 'Ширина', 'Длина', 'Единица измерения размера', 'Место создания', 'Количество составляющих',
                 'Ключевые слова', 'URL предмета на сайте музея', 'Высота', 'Идентификатор статуса предмета',
                 'Краткое описание истории бытования (провенанс) предмета',
                 'Точность задания времени (день, месяц, год, век, эпоха).',
                 'Интервал времени создания предмета (начало)',
                 'Интервал времени создания предмета (окончание)',

                 ]
data_cleaned.drop(cols_for_drop, axis=1, inplace=True)

# %%
data_cleaned
# Out:
#                                    Наименование предмета  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 57249                  Портрет Анны Андреевны Ахматовой.
# 57250                                              Зима.
# 57251                       Лестница. Ленинский проспект
# 57252                                       Без названия
# 57253                                            Завтрак
#
#                                                 Автор  \
# 0           ["Малевич Казимир Северинович 1879-1935"]
# 1         ["Малевич Казимир Северинович (1879-1935)"]
# 2         ["Малевич Казимир Северинович (1879-1935)"]
# 3           ["Малевич Казимир Северинович 1879-1935"]
# 4         ["Малевич Казимир Северинович (1879-1935)"]
# ...                                               ...
# 57249  ["Петров-Водкин Кузьма Сергеевич (1878-1939)"]
# 57250          ["Павлов Семен Андреевич 1893 - 1941"]
# 57251          ["Волков Владимир Петрович 1923-1987"]
# 57252   ["Добротворский Сергей Николаевич 1959-1997"]
# 57253           ["Белютин Элий Михайлович род. 1925"]
#
#                                                    Items  \
# 0                                       ["бумага, тушь"]
# 1             ["бумага, графитный карандаш, растушевка"]
# 2                           ["бумага верже, тушь, перо"]
# 3                             ["бумага, черные чернила"]
# 4      ["бумага, бумага цветная, тушь, гуашь, наклейка"]
# ...                                                  ...
# 57249                                   ["холст, масло"]
# 57250                                   ["холст, масло"]
# 57251                                   ["холст, масло"]
# 57252                         ["холст на фанере, масло"]
# 57253                                   ["холст, масло"]
#
#       Дата создания предмета (строка)  \
# 0                                1908
# 1                        Конец 1900-х
# 2                        Ок. 1908 (?)
# 3        Конец 1920-х - начало 1930-х
# 4       Сер.-2-ая половина 1900-х (?)
# ...                               ...
# 57249                            1922
# 57250                            1923
# 57251                            1987
# 57252                Конец 1980-х гг.
# 57253                            1999
#
#                                                 Описание  \
# 0      В вертикальной прямоугольной рамке декоративны...
# 1      Портрет женщины в шляпе с пером (фронтально, о...
# 2      Три виньетки. Слева: овальная виньетка с цвето...
# 3      Один под другим, в рамках: два женских портрет...
# 4      В круге:  на фоне с цветочными узорами - поясн...
# ...                                                  ...
# 57249  Ахматова изображена по плечи, с поворотом слег...
# 57250  Городской пейзаж. На первом плане: справа руин...
# 57251  Абстрактная композиция состоящая из прямоуголь...
# 57252  В верхней части картины - летящий  влево желты...
# 57253  Абстрактно-предметная композиция. В центре изо...
#
#                                              Изображение  \
# 0      [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 1      [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 2      [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 3      [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 4      [{"url":"http://goskatalog.ru/muzfo-imaginator...
# ...                                                  ...
# 57249  [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 57250  [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 57251  [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 57252  [{"url":"http://goskatalog.ru/muzfo-imaginator...
# 57253  [{"url":"http://goskatalog.ru/muzfo-imaginator...
#
#        Регистрационный номер Госкаталога  Дата регистрации записи. Типология
# 0                             10479770.0  2018-01-31T12:54:54.729Z   графика
# 1                             10479769.0  2018-01-31T12:54:54.729Z   графика
# 2                             10479768.0  2018-01-31T12:54:54.729Z   графика
# 3                             10479767.0  2018-01-31T12:54:54.729Z   графика
# 4                             10479766.0  2018-01-31T12:54:54.729Z   графика
# ...                                  ...                       ...       ...
# 57249                          9876002.0  2017-12-11T11:44:01.596Z  живопись
# 57250                          9876001.0  2017-12-11T11:44:01.596Z  живопись
# 57251                          9876000.0  2017-12-11T11:44:01.596Z  живопись
# 57252                          9875998.0  2017-12-11T11:44:01.596Z  живопись
# 57253                          9875996.0  2017-12-11T11:44:01.596Z  живопись
#
# [57254 rows x 9 columns]

# %%
data_cleaned.columns
# Out:
# Index(['Наименование предмета', 'Автор', 'Items',
#        'Дата создания предмета (строка)', 'Описание', 'Изображение',
#        'Регистрационный номер Госкаталога', 'Дата регистрации записи.',
#        'Типология'],
#       dtype='object')

# %%
# Переименовываем столбцы
data_cleaned = data_cleaned.rename(columns={
    'Наименование предмета': 'title',
    'Автор': 'author',
    'Items': 'items',
    'Описание': 'description',
    'Изображение': 'image_url',
    'Регистрационный номер Госкаталога': 'catalog_num',
    'Дата регистрации записи.': 'registration_date',
    'Типология': 'typology',
    'Дата создания предмета (строка)': 'creation_date',

})

# %%
data_cleaned.columns
# Out:
# Index(['title', 'author', 'items', 'creation_date', 'description', 'image_url',
#        'catalog_num', 'registration_date', 'typology'],
#       dtype='object')

# %% [markdown]
# ## Разделение столбца Автор

# %%
data_cleaned[['author_lastname', 'author_name', 'author_patronymic', 'other_info']] = (data_cleaned['author']
                                                                                       .str.replace('["', '')
                                                                                       .str.replace('"]', '')
                                                                                       .str.split(' ', n=3,
                                                                                                  expand=True))
data_cleaned.drop('author', axis=1, inplace=True)

# %% [markdown]
# ## Выбор графики и живописи

# %%
data_cleaned['typology'].value_counts()
# Out:
# typology
# графика                                              31225
# предметы прикладного искусства, быта и этнографии     9973
# живопись                                              4482
# документы                                             4033
# скульптура                                            2493
# предметы нумизматики                                  2175
# прочие                                                1934
# фотографии и негативы                                  939
# Name: count, dtype: int64

# %%
# Приводим столбец 'Типология' к нижнему регистру и удаляем лишние пробелы
data_cleaned['typology'] = data_cleaned['typology'].str.strip().str.lower()

# Выбираем строки с типологией 'графика' или 'живопись'
picture_data = data_cleaned[data_cleaned['typology'].isin(['графика', 'живопись'])].reset_index(drop=True)

# %%
picture_data
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                    items  \
# 0                                       ["бумага, тушь"]
# 1             ["бумага, графитный карандаш, растушевка"]
# 2                           ["бумага верже, тушь, перо"]
# 3                             ["бумага, черные чернила"]
# 4      ["бумага, бумага цветная, тушь, гуашь, наклейка"]
# ...                                                  ...
# 35702                                   ["холст, масло"]
# 35703                                   ["холст, масло"]
# 35704                                   ["холст, масло"]
# 35705                         ["холст на фанере, масло"]
# 35706                                   ["холст, масло"]
#
#                         creation_date  \
# 0                                1908
# 1                        Конец 1900-х
# 2                        Ок. 1908 (?)
# 3        Конец 1920-х - начало 1930-х
# 4       Сер.-2-ая половина 1900-х (?)
# ...                               ...
# 35702                            1922
# 35703                            1923
# 35704                            1987
# 35705                Конец 1980-х гг.
# 35706                            1999
#
#                                              description  \
# 0      В вертикальной прямоугольной рамке декоративны...
# 1      Портрет женщины в шляпе с пером (фронтально, о...
# 2      Три виньетки. Слева: овальная виньетка с цвето...
# 3      Один под другим, в рамках: два женских портрет...
# 4      В круге:  на фоне с цветочными узорами - поясн...
# ...                                                  ...
# 35702  Ахматова изображена по плечи, с поворотом слег...
# 35703  Городской пейзаж. На первом плане: справа руин...
# 35704  Абстрактная композиция состоящая из прямоуголь...
# 35705  В верхней части картины - летящий  влево желты...
# 35706  Абстрактно-предметная композиция. В центре изо...
#
#                                                image_url  catalog_num  \
# 0      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479770.0
# 1      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479769.0
# 2      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479768.0
# 3      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479767.0
# 4      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479766.0
# ...                                                  ...          ...
# 35702  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9876002.0
# 35703  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9876001.0
# 35704  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9876000.0
# 35705  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9875998.0
# 35706  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9875996.0
#
#               registration_date  typology author_lastname author_name  \
# 0      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 1      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 2      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 3      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 4      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# ...                         ...       ...             ...         ...
# 35702  2017-12-11T11:44:01.596Z  живопись   Петров-Водкин      Кузьма
# 35703  2017-12-11T11:44:01.596Z  живопись          Павлов       Семен
# 35704  2017-12-11T11:44:01.596Z  живопись          Волков    Владимир
# 35705  2017-12-11T11:44:01.596Z  живопись   Добротворский      Сергей
# 35706  2017-12-11T11:44:01.596Z  живопись         Белютин        Элий
#
#       author_patronymic   other_info
# 0           Северинович    1879-1935
# 1           Северинович  (1879-1935)
# 2           Северинович  (1879-1935)
# 3           Северинович    1879-1935
# 4           Северинович  (1879-1935)
# ...                 ...          ...
# 35702         Сергеевич  (1878-1939)
# 35703         Андреевич  1893 - 1941
# 35704          Петрович    1923-1987
# 35705        Николаевич    1959-1997
# 35706        Михайлович    род. 1925
#
# [35707 rows x 12 columns]

# %%
# Выбор данных, которые не относятся к 'графика' и 'живопись'
other_data = data_cleaned[~data_cleaned['typology'].isin(['графика', 'живопись'])]
other_data.to_csv(f'{df_path}/other_data.csv', index=False)

# %% [markdown]
# ## Очистка столбца Материалы

# %%
picture_data['items'] = picture_data['items'].str.replace('["', '').str.replace('"]', '')

# %%
picture_data['items']
# Out:
# 0                                         бумага, тушь
# 1               бумага, графитный карандаш, растушевка
# 2                             бумага верже, тушь, перо
# 3                               бумага, черные чернила
# 4        бумага, бумага цветная, тушь, гуашь, наклейка
#                              ...
# 35702                                     холст, масло
# 35703                                     холст, масло
# 35704                                     холст, масло
# 35705                           холст на фанере, масло
# 35706                                     холст, масло
# Name: items, Length: 35707, dtype: object

# %%
synonyms = {
    r'^графитный карандаш$': 'карандаш',
    r'^цветной карандаш$': 'карандаш',
    r'^карандаш графитовый$': 'карандаш',
    r'^карандаш графитный$': 'карандаш',
    r'^цифровая печать$': 'печать',
    r'^типографская печать$': 'печать',
    r'^альбуминовая печать$': 'печать',
    r'^лит$': 'литография',
    r'^литография с тоном$': 'литография',
    r'^литография цветная$': 'литография',
    r'^бумага верже$': 'бумага',
    r'^роспись полихромная$': 'роспись',
    r'^б.$': 'бумага',
    r'^черные чернила$': 'тушь',
    r'^акв$': 'акварель',
    r'^акв\.$': 'акварель',
    r'^гравюра пунктиром$': 'гравюра',
    r'^гравюра на дереве$': 'гравюра',
    r'^карандаш итальянский$': 'карандаш',
    r'^гравюра резцом$': 'гравюра',
    r'^бумага на картоне$': 'бумага',
    r'^бумага серая$': 'бумага',
    r'^черный карандаш$': 'карандаш',
    r'^граф\. кар\.$': 'карандаш',
    r'^карандаши цветные$': 'карандаш',
    r'^карандаш черный$': 'карандаш',
    r'^акварель черная$': 'акварель',
    r'^линогравюра$': 'гравюра',
    r'^шариковая ручка$': 'чернила',
    r'^хромолитография$': 'литография',
    r'^автолитография$': 'литография',
    r'^литография раскрашенная$': 'литография',
    r'^фанера$': 'дерево',
    r'^акварельарель черная$': 'акварель',
    r'^цветная литография$': 'литография',
    r'^граф\. кар$': 'карандаш',
    r'^холст на картоне$': 'холст',
    r'^карандаш угольный$': 'карандаш',
    r'^бумага цветная$': 'бумага',
    r'^бумага желтая$': 'бумага',
    r'^бумага черная$': 'бумага',
    r'^черная акварель$': 'акварель',
    r'^акварель атинта$': 'акварель',
    r'^\\nмасло$': 'масло',
    r'^гравюра цветная$': 'гравюра',
    r'^итальянский карандаш$': 'карандаш',
    r'^гравюра раскрашенная$': 'гравюра',
    r'^монотипия цветная$': 'монотипия',
    r'^уголь прессованный$': 'уголь',
    r'^граф\.кар\.$': 'картон',
    r'^бумага желтоватая$': 'бумага',
    r'^бумага коричневая$': 'бумага',
    r'^цветные карандаши$': 'карандаш',
    r'^карандаш свинцовый$': 'карандаш',
    r'^холст,масло$': 'масло',
    r'^масляная пастель$': 'пастель',
    r'^наклеенная на белую бумагу$': 'аппликация',
    r'^наклейки$': 'аппликация',
    r'^бумага мелованная$': 'бумага',
    r'^ксилография цветная$': 'ксилография',
    r'^карандаш литографский$': 'литография',
    r'^тушь цветная$': 'тушь',
    r'^мягкий лак$': 'лак',
    r'^гравюра на картоне$': 'гравюра',
    r'^картон мелованный$': 'картон',
    r'^бронзовая краска$': 'бронза',
    r'^к\.$': 'картон',
    r'^бумага голубая$': 'бумага',
    r'^бумага оберточная$': 'бумага',
    r'^слоновая кость\\nминиатюра$': 'миниатюра',
    r'^автолитография цветная$': 'литография',
    r'^гравюра резцом раскрашенная$': 'гравюра',
    r'^линогравюра цветная$': 'гравюра',
    r'^черн. акв$': 'акварель',
    r'^холст,\\nмасло$': 'масло',
    r'^цв. кар$': 'картон',
    r'^бумага зеленая$': 'бумага'

}

# %%
def clean_material(material, synonyms):
    if pd.isna(material):
        material = ''
    else:
        material = material.strip().lower()
    for old, new in synonyms.items():
        material = re.sub(old, new, material)
    return material

# %%
def analyze_top_materials(dataframe, column_name, synonyms, top_n=50):
    all_materials = dataframe[column_name].str.split(', ').explode()
    all_materials_cleaned = all_materials.progress_apply(lambda material: clean_material(material, synonyms))
    material_counts = Counter(all_materials_cleaned)
    counter = pd.DataFrame.from_dict(material_counts, orient='index', columns=['Count'])
    counter_cleaned = counter.sort_values(by='Count', ascending=False)
    top_materials = counter_cleaned.head(top_n)

    return top_materials.index.tolist()

# %%
top_50 = analyze_top_materials(picture_data, 'items', synonyms)
top_50
# Out:
# Processing rows...: 100%|███████████████████████████████████| 74848/74848 [00:08<00:00, 8835.17it/s]
# ['бумага',
#  'карандаш',
#  'акварель',
#  'тушь',
#  'масло',
#  'литография',
#  'холст',
#  'гуашь',
#  'перо',
#  'гравюра',
#  'уголь',
#  'ксилография',
#  'графит',
#  'белила',
#  'картон',
#  'темпера',
#  'офорт',
#  'пастель',
#  'сепия',
#  'чернила',
#  'кисть',
#  'дерево',
#  'сангина',
#  'калька',
#  'хромолит',
#  'аппликация',
#  'фломастер',
#  'оргалит',
#  'бронза',
#  'лак',
#  'коллаж',
#  'монотипия',
#  'акрил',
#  'растушка',
#  'соус',
#  'процарапывание',
#  'смешанная техника',
#  'акватинта',
#  'цинкография',
#  'мел',
#  'серебро',
#  'сухая игла',
#  'бистр',
#  'ламповая копоть',
#  'левкас',
#  'миниатюра',
#  'золотая краска',
#  'клеевая краска',
#  'типографский оттиск',
#  'живопись яичными красками']

# %%
# Функция для обработки строки
def process_items(item):
    if pd.isna(item):
        return ''
    # Разделяем строку на отдельные материалы
    materials = item.split(', ')
    # Заменяем синонимы
    materials = [material for material in materials if material in top_50]
    # Удаляем дубликаты и сортируем
    return ','.join(sorted(set(materials)))

# %%
# Преобразуем столбец items в key_words
picture_data['key_materials'] = picture_data['items'].progress_apply(process_items)
# Out:
# Processing rows...: 100%|█████████████████████████████████| 35707/35707 [00:00<00:00, 216571.65it/s]

# %%
picture_data['key_materials']
# Out:
# 0              бумага,тушь
# 1                   бумага
# 2                перо,тушь
# 3                   бумага
# 4        бумага,гуашь,тушь
#                ...
# 35702          масло,холст
# 35703          масло,холст
# 35704          масло,холст
# 35705                масло
# 35706          масло,холст
# Name: key_materials, Length: 35707, dtype: object

# %%
picture_data.to_csv(f'{df_path}/picture_data_with_key_material.csv', index=False, encoding='utf-8', sep=';')

# %% [markdown]
# ## Очистка столбца с датами

# %%
# функция для предобработки дат
def process_date(date_str):
    try:
        # Проверка на NaN
        if pd.isna(date_str):
            return "Неизвестно"

        # Преобразуем строку
        date_str = re.sub(r"[^\w\s\-]", "", date_str).lower()
        date_str = date_str.replace("х", "х годов")

        # Обработка "конец" (например, "конец 1920-х" или "конец 1900-х")
        if "конец" in date_str:
            decades = re.findall(r"\d{3,4}", date_str)
            if len(decades) == 1:
                start = int(decades[0])
                if start % 100 != 0:
                    return f"{start + 6}-{start + 9}"  # для конца десятилетия, например, конец 1920-х -> 1926-1929
                else:
                    return f"{start + 96}-{start + 99}"  # для конца десятилетия после 1900-х, например, конец 1900-х -> 1996-1999
            elif len(decades) == 2:
                return f"{decades[0]}-{decades[1]}"

        # Обработка "начало" (например, "начало 1920-х")
        if "начало" in date_str:
            decades = re.findall(r"\d{3,4}", date_str)
            if len(decades) == 1:
                start = int(decades[0])
                return f"{start}-{start + 9}"  # для начала десятилетия, например, начало 1920-х -> 1920-1929
            elif len(decades) == 2:
                return f"{decades[0]}-{decades[1]}"

        # Обработка "середина" (например, "середина 1920-х")
        if "середина" in date_str:
            decades = re.findall(r"\d{3,4}", date_str)
            if len(decades) == 1:
                start = int(decades[0])
                return f"{start + 4}-{start + 5}"

        # Обработка "1-я половина" и "2-я половина"
        if "1-я половина" in date_str or "1-ая половина" in date_str:
            decades = re.findall(r"\d{3,4}", date_str)
            if len(decades) == 1:
                start = int(decades[0])
                return f"{start}-{start + 49}"

        if "2-я половина" in date_str or "2-ая половина" in date_str:
            decades = re.findall(r"\d{3,4}", date_str)
            if len(decades) == 1:
                start = int(decades[0])
                return f"{start + 50}-{start + 99}"

        # Обработка диапазонов
        if "-" in date_str:
            years = re.findall(r"\d{4}", date_str)
            if len(years) == 2:
                start_year = int(years[0])
                end_year = int(years[1])
                if start_year >= 1000 and end_year <= 3000:
                    return f"{start_year}-{end_year}"
            elif len(years) == 1:
                return f"{years[0]}"

        # Обработка "около"
        if "ок" in date_str or "примерно" in date_str:
            years = re.findall(r"\d{4}", date_str)
            if len(years) == 1:
                return years[0]

        # Обработка одиночных годов
        years = re.findall(r"\d{4}", date_str)
        if len(years) == 1:
            return years[0]
        # Если ничего не найдено
        return "Неизвестно"
    except:
        return "Ошибка"

# %%
# Обработка всех строк
picture_data['date_cleaned'] = picture_data['creation_date'].progress_apply(process_date)
picture_data[['date_cleaned', 'creation_date']]
# Out:
# Processing rows...: 100%|█████████████████████████████████| 35707/35707 [00:00<00:00, 105571.25it/s]
#       date_cleaned                   creation_date
# 0             1908                            1908
# 1        1996-1999                    Конец 1900-х
# 2             1908                    Ок. 1908 (?)
# 3        1920-1930    Конец 1920-х - начало 1930-х
# 4        1950-1999   Сер.-2-ая половина 1900-х (?)
# ...            ...                             ...
# 35702         1922                            1922
# 35703         1923                            1923
# 35704         1987                            1987
# 35705    1986-1989                Конец 1980-х гг.
# 35706         1999                            1999
#
# [35707 rows x 2 columns]

# %%
def categorize_date(date_str):
    try:
        # Проверка на NaN и ошибки
        if pd.isna(date_str) or date_str == "Неизвестно":
            return "Неизвестно"

        # Обработка диапазонов (например, 1920-1930)
        if "-" in date_str:
            years = re.findall(r"\d{4}", date_str)
            if len(years) == 2:
                start_year = int(years[0])
                end_year = int(years[1])
                avg_year = (start_year + end_year) // 2
            else:
                return "Неизвестно"
        else:
            avg_year = int(date_str)

        # Определяем век на основе среднего года
        century = (avg_year // 100) + 1

        # Определяем, первая или вторая половина века
        if avg_year % 100 <= 50:
            return f"1-я пол.{century}"
        else:
            return f"2-я пол.{century}"

    except:
        return f"Ошибка"

# %%
picture_data['date_category'] = picture_data['date_cleaned'].progress_apply(categorize_date)
picture_data[['date_category', 'date_cleaned', 'creation_date']]
# Out:
# Processing rows...: 100%|█████████████████████████████████| 35707/35707 [00:00<00:00, 181011.27it/s]
#       date_category date_cleaned                   creation_date
# 0        1-я пол.20         1908                            1908
# 1        2-я пол.20    1996-1999                    Конец 1900-х
# 2        1-я пол.20         1908                    Ок. 1908 (?)
# 3        1-я пол.20    1920-1930    Конец 1920-х - начало 1930-х
# 4        2-я пол.20    1950-1999   Сер.-2-ая половина 1900-х (?)
# ...             ...          ...                             ...
# 35702    1-я пол.20         1922                            1922
# 35703    1-я пол.20         1923                            1923
# 35704    2-я пол.20         1987                            1987
# 35705    2-я пол.20    1986-1989                Конец 1980-х гг.
# 35706    2-я пол.20         1999                            1999
#
# [35707 rows x 3 columns]

# %%
picture_data.to_csv(f'{df_path}/picture_data_with_date_and_materials.csv', sep=';', encoding='utf-8', index=False)

# %% [markdown]
# # Поиск ключевых слов по названию и описанию

# %%
import spacy
from tqdm.notebook import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# !python -m spacy download ru_core_news_sm

# %%
# Загрузка модели spacy для русского языка
nlp = spacy.load("ru_core_news_sm")

# %%
# Функция для лемматизации текста с использованием spacy
def lemmatize_text_spacy(text):
    doc = nlp(text)
    lemmatized_words = [token.lemma_ for token in doc]
    return ' '.join(lemmatized_words)

# %%
def extract_keywords_with_tfidf(df, top_n=20):
    # Объединяем описание и название в единый текст и лемматизируем
    df['combined_text'] = df['description'] + ' ' + df['title']
    df['lemmatized_text'] = df['combined_text'].apply(lemmatize_text_spacy)

    # Вычисляем TF-IDF на основе лемматизированного текста
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(df['lemmatized_text'])
    feature_names = vectorizer.get_feature_names_out()

    df['key_words'] = ''

    for index in tqdm(range(len(df)), total=len(df), desc="Processing rows", ncols=100):
        # Получаем TF-IDF веса для текущей строки
        tfidf_vector = tfidf_matrix[index].toarray().flatten()
        top_indices = tfidf_vector.argsort()[-top_n:][::-1]

        # Извлекаем ключевые слова
        key_words = [feature_names[i] for i in top_indices if tfidf_vector[i] > 0]

        # Сохраняем ключевые слова
        df.at[index, 'key_words'] = ','.join(key_words)

    # Удаляем временные колонки
    df.drop(columns=['combined_text', 'lemmatized_text'], inplace=True)

    return df

# %%
df = extract_keywords_with_tfidf(picture_data)
# Out:
# Processing rows:   0%|                                                    | 0/35707 [00:00<?, ?it/s]

# %%
# Сохранение результата в CSV файл
df.to_csv(f'{df_path}/picture_data_with_keywords.csv', index=False, sep=';', encoding='utf-8')

# %%
df
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                         creation_date  \
# 0                                1908
# 1                        Конец 1900-х
# 2                        Ок. 1908 (?)
# 3        Конец 1920-х - начало 1930-х
# 4       Сер.-2-ая половина 1900-х (?)
# ...                               ...
# 35702                            1922
# 35703                            1923
# 35704                            1987
# 35705                Конец 1980-х гг.
# 35706                            1999
#
#                                              description  \
# 0      В вертикальной прямоугольной рамке декоративны...
# 1      Портрет женщины в шляпе с пером (фронтально, о...
# 2      Три виньетки. Слева: овальная виньетка с цвето...
# 3      Один под другим, в рамках: два женских портрет...
# 4      В круге:  на фоне с цветочными узорами - поясн...
# ...                                                  ...
# 35702  Ахматова изображена по плечи, с поворотом слег...
# 35703  Городской пейзаж. На первом плане: справа руин...
# 35704  Абстрактная композиция состоящая из прямоуголь...
# 35705  В верхней части картины - летящий  влево желты...
# 35706  Абстрактно-предметная композиция. В центре изо...
#
#                                                image_url  catalog_num  \
# 0      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479770.0
# 1      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479769.0
# 2      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479768.0
# 3      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479767.0
# 4      [{"url":"http://goskatalog.ru/muzfo-imaginator...   10479766.0
# ...                                                  ...          ...
# 35702  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9876002.0
# 35703  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9876001.0
# 35704  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9876000.0
# 35705  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9875998.0
# 35706  [{"url":"http://goskatalog.ru/muzfo-imaginator...    9875996.0
#
#               registration_date  typology author_lastname author_name  \
# 0      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 1      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 2      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 3      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 4      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# ...                         ...       ...             ...         ...
# 35702  2017-12-11T11:44:01.596Z  живопись   Петров-Водкин      Кузьма
# 35703  2017-12-11T11:44:01.596Z  живопись          Павлов       Семен
# 35704  2017-12-11T11:44:01.596Z  живопись          Волков    Владимир
# 35705  2017-12-11T11:44:01.596Z  живопись   Добротворский      Сергей
# 35706  2017-12-11T11:44:01.596Z  живопись         Белютин        Элий
#
#       author_patronymic   other_info      key_materials date_cleaned  \
# 0           Северинович    1879-1935        бумага,тушь         1908
# 1           Северинович  (1879-1935)             бумага    1996-1999
# 2           Северинович  (1879-1935)          перо,тушь         1908
# 3           Северинович    1879-1935             бумага    1920-1930
# 4           Северинович  (1879-1935)  бумага,гуашь,тушь    1950-1999
# ...                 ...          ...                ...          ...
# 35702         Сергеевич  (1878-1939)        масло,холст         1922
# 35703         Андреевич  1893 - 1941        масло,холст         1923
# 35704          Петрович    1923-1987        масло,холст         1987
# 35705        Николаевич    1959-1997              масло    1986-1989
# 35706        Михайлович    род. 1925        масло,холст         1999
#
#       date_category                                          key_words
# 0        1-я пол.20  мотив,декоративный,нанизанными,стержень,диск,ц...
# 1        2-я пол.20  младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2        1-я пол.20  виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3        1-я пол.20  изображенной,недлинный,распущенные,платье,женс...
# 4        2-я пол.20  круг,крапинка,вставка,цветочный,картон,портрет...
# ...             ...                                                ...
# 35702    1-я пол.20  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703    1-я пол.20  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704    2-я пол.20  ленинский,овала,проспект,напоминать,цветной,со...
# 35705    2-я пол.20  расклешенной,планета,картина,парить,воздух,кра...
# 35706    2-я пол.20  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
# [35707 rows x 16 columns]

# %% [markdown]
# # Сохранение датафрейма для кластеризации и загрузка в бд

# %%
df.drop(['date_cleaned', 'key_materials', 'other_info', 'creation_date'], inplace=True, axis=1)

# %%
columns_for_db = [
    'image_url', 'catalog_num', 'registration_date', 'author_name', 'author_patronymic',
]

# %%
def reformate_url(column):
    if pd.isna(column):
        return None
    match = re.search(r'"url":"(http[s]?://[^"]+)"', column)
    if match:
        return match.group(1)
    return None

# %%
df['image_url'] = df['image_url'].apply(reformate_url)

# %%
df['image_url']
# Out:
# 0        http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 1        http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 2        http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 3        http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 4        http://goskatalog.ru/muzfo-imaginator/rest/ima...
#                                ...
# 35702    http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35703    http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35704    http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35705    http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35706    http://goskatalog.ru/muzfo-imaginator/rest/ima...
# Name: image_url, Length: 35707, dtype: object

# %%
df.to_csv(f'{df_path}/data_for_database.csv', index=False, sep=';', encoding='utf-8')

# %%
df = pd.read_csv(f'{df_path}/data_for_database.csv', sep=';', encoding='utf-8')

# %%
df.drop(columns_for_db, inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['title', 'items', 'description', 'typology', 'author_lastname',
#        'date_category', 'key_words'],
#       dtype='object')

# %%
df.rename(columns={
    'author_lastname': 'author',
}, inplace=True)

# %%
df.to_csv(f'{df_path}/data_for_clasterisation.csv', index=False, sep=';', encoding='utf-8')

# %%
df
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                                              description  typology  \
# 0      В вертикальной прямоугольной рамке декоративны...   графика
# 1      Портрет женщины в шляпе с пером (фронтально, о...   графика
# 2      Три виньетки. Слева: овальная виньетка с цвето...   графика
# 3      Один под другим, в рамках: два женских портрет...   графика
# 4      В круге:  на фоне с цветочными узорами - поясн...   графика
# ...                                                  ...       ...
# 35702  Ахматова изображена по плечи, с поворотом слег...  живопись
# 35703  Городской пейзаж. На первом плане: справа руин...  живопись
# 35704  Абстрактная композиция состоящая из прямоуголь...  живопись
# 35705  В верхней части картины - летящий  влево желты...  живопись
# 35706  Абстрактно-предметная композиция. В центре изо...  живопись
#
#               author date_category  \
# 0            Малевич    1-я пол.20
# 1            Малевич    2-я пол.20
# 2            Малевич    1-я пол.20
# 3            Малевич    1-я пол.20
# 4            Малевич    2-я пол.20
# ...              ...           ...
# 35702  Петров-Водкин    1-я пол.20
# 35703         Павлов    1-я пол.20
# 35704         Волков    2-я пол.20
# 35705  Добротворский    2-я пол.20
# 35706        Белютин    2-я пол.20
#
#                                                key_words
# 0      мотив,декоративный,нанизанными,стержень,диск,ц...
# 1      младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2      виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3      изображенной,недлинный,распущенные,платье,женс...
# 4      круг,крапинка,вставка,цветочный,картон,портрет...
# ...                                                  ...
# 35702  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704  ленинский,овала,проспект,напоминать,цветной,со...
# 35705  расклешенной,планета,картина,парить,воздух,кра...
# 35706  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
# [35707 rows x 7 columns]

# %% [markdown]
# # Рекомендательная система

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from tqdm import tqdm
from transformers import BertTokenizer, BertModel
import pickle

# %%
folder_path = './data'
df_path = folder_path + '/data_for_clasterisation.csv'

# %%
# Инициализация tqdm_pandas
tqdm.pandas()

# %%
df = pd.read_csv(df_path, sep=';', encoding='utf-8')
df
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                                              description  typology  \
# 0      В вертикальной прямоугольной рамке декоративны...   графика
# 1      Портрет женщины в шляпе с пером (фронтально, о...   графика
# 2      Три виньетки. Слева: овальная виньетка с цвето...   графика
# 3      Один под другим, в рамках: два женских портрет...   графика
# 4      В круге:  на фоне с цветочными узорами - поясн...   графика
# ...                                                  ...       ...
# 35702  Ахматова изображена по плечи, с поворотом слег...  живопись
# 35703  Городской пейзаж. На первом плане: справа руин...  живопись
# 35704  Абстрактная композиция состоящая из прямоуголь...  живопись
# 35705  В верхней части картины - летящий  влево желты...  живопись
# 35706  Абстрактно-предметная композиция. В центре изо...  живопись
#
#               author date_category  \
# 0            Малевич    1-я пол.20
# 1            Малевич    2-я пол.20
# 2            Малевич    1-я пол.20
# 3            Малевич    1-я пол.20
# 4            Малевич    2-я пол.20
# ...              ...           ...
# 35702  Петров-Водкин    1-я пол.20
# 35703         Павлов    1-я пол.20
# 35704         Волков    2-я пол.20
# 35705  Добротворский    2-я пол.20
# 35706        Белютин    2-я пол.20
#
#                                                key_words
# 0      мотив,декоративный,нанизанными,стержень,диск,ц...
# 1      младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2      виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3      изображенной,недлинный,распущенные,платье,женс...
# 4      круг,крапинка,вставка,цветочный,картон,портрет...
# ...                                                  ...
# 35702  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704  ленинский,овала,проспект,напоминать,цветной,со...
# 35705  расклешенной,планета,картина,парить,воздух,кра...
# 35706  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
# [35707 rows x 7 columns]

# %%
# очистка пропусков
df['key_words'] = df['key_words'].fillna('')
df['author'] = df['author'].fillna('')
df['key_words'] = df['key_words'] + ',' + df['author']

# %% [markdown]
# ## 2. Кодирование признаков

# %%
# Загрузка предобученной модели для русского языка
model_name = 'DeepPavlov/rubert-base-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Функция для получения эмбеддингов с помощью RuBERT
def get_embeddings(texts):
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt", max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings

# %%
def get_item_embeddings(data):
    descriptions = data['key_words'].tolist()
    embeddings = []
    # Получаем эмбеддинги для каждого экспоната
    for desc in tqdm(descriptions, desc="Генерация эмбеддингов для описаний", unit="экспонат"):
        embedding = get_embeddings([desc])
        embeddings.append(embedding)
    # Преобразуем список эмбеддингов в numpy массив
    embeddings = torch.cat(embeddings, dim=0).numpy()
    return embeddings

# %%
# Функция для дополнения эмбеддинга запроса до требуемой размерности
def resize_embedding(query_embedding, target_dim):
    current_dim = query_embedding.shape[1]

    # Если текущая размерность уже совпадает с целевой, возвращаем эмбеддинг без изменений
    if current_dim == target_dim:
        return query_embedding

    # Если текущая размерность меньше целевой, дополняем нулями
    if current_dim < target_dim:
        padding = np.zeros((query_embedding.shape[0], target_dim - current_dim))
        return np.hstack([query_embedding, padding])

    # Если текущая размерность больше целевой, обрезаем лишние элементы
    return query_embedding[:, :target_dim]

# %%
embeddings = get_item_embeddings(df)
# Out:
# Генерация эмбеддингов для описаний: 100%|██████████| 35707/35707 [53:31<00:00, 11.12экспонат/s]

# %%
embeddings.shape
# Out:
# (35707, 768)

# %%
# !pip install pyarrow

# %%
df['embeddings'] = list(embeddings)
# Сохраняем в Parquet (меньше места, быстрее загрузка)
df.to_parquet(folder_path + "dataset_with_embeddings.parquet", index=False, engine="pyarrow")

# %%
df = pd.read_parquet(folder_path + "dataset_with_embeddings.parquet")
df
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                                              description  typology  \
# 0      В вертикальной прямоугольной рамке декоративны...   графика
# 1      Портрет женщины в шляпе с пером (фронтально, о...   графика
# 2      Три виньетки. Слева: овальная виньетка с цвето...   графика
# 3      Один под другим, в рамках: два женских портрет...   графика
# 4      В круге:  на фоне с цветочными узорами - поясн...   графика
# ...                                                  ...       ...
# 35702  Ахматова изображена по плечи, с поворотом слег...  живопись
# 35703  Городской пейзаж. На первом плане: справа руин...  живопись
# 35704  Абстрактная композиция состоящая из прямоуголь...  живопись
# 35705  В верхней части картины - летящий  влево желты...  живопись
# 35706  Абстрактно-предметная композиция. В центре изо...  живопись
#
#               author date_category  \
# 0            Малевич    1-я пол.20
# 1            Малевич    2-я пол.20
# 2            Малевич    1-я пол.20
# 3            Малевич    1-я пол.20
# 4            Малевич    2-я пол.20
# ...              ...           ...
# 35702  Петров-Водкин    1-я пол.20
# 35703         Павлов    1-я пол.20
# 35704         Волков    2-я пол.20
# 35705  Добротворский    2-я пол.20
# 35706        Белютин    2-я пол.20
#
#                                                key_words  \
# 0      мотив,декоративный,нанизанными,стержень,диск,ц...
# 1      младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2      виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3      изображенной,недлинный,распущенные,платье,женс...
# 4      круг,крапинка,вставка,цветочный,картон,портрет...
# ...                                                  ...
# 35702  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704  ленинский,овала,проспект,напоминать,цветной,со...
# 35705  расклешенной,планета,картина,парить,воздух,кра...
# 35706  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
#                                               embeddings
# 0      [0.58408934, 0.0099625345, 0.5078726, -0.09612...
# 1      [0.24424578, -0.07890896, 0.4376867, -0.012639...
# 2      [0.46791208, 0.33006114, 0.11194826, -0.200296...
# 3      [0.52606016, 0.16979823, 0.19851033, -0.142191...
# 4      [0.45312378, 0.23196974, 0.4026124, -0.0648039...
# ...                                                  ...
# 35702  [0.29600233, 0.11324207, 0.48956913, -0.145708...
# 35703  [0.115966424, -0.49209934, 0.6091171, -0.14707...
# 35704  [0.31625056, 0.23952124, 0.15789297, -0.197009...
# 35705  [0.14807168, -0.113046505, 0.51217633, -0.1758...
# 35706  [0.09742064, 0.35496908, 0.73671126, 0.1387997...
#
# [35707 rows x 8 columns]

# %% [markdown]
# ## Рекомендательная система на основе KMeans

# %%
def create_kmeans_model(embeddings, n_clusters=20):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(embeddings)
    return kmeans

# %%
kmeans_model = create_kmeans_model(embeddings, n_clusters=20)
kmeans_model.cluster_centers_.shape
# Out:
# (20, 768)

# %%
from joblib import dump, load

# Сохранение модели
dump(kmeans_model, './data/kmeans_model.joblib')
# Out:
# ['./data/kmeans_model.joblib']

# %%
# Загрузка модели
kmeans_model = load('./data/kmeans_model.joblib')
kmeans_model.cluster_centers_.shape
# Out:
# (20, 768)

# %%
# Прогнозируем, к какому кластеру принадлежит каждый экспонат
cluster_labels = kmeans_model.predict(embeddings)

# Добавляем информацию о кластере в данные
df['cluster'] = cluster_labels

# %%
df.to_parquet(folder_path + 'data_with_clasters.parquet', index=False, engine="pyarrow")

# %%
df = pd.read_parquet(folder_path + 'data_with_clasters.parquet')
df
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                                              description  typology  \
# 0      В вертикальной прямоугольной рамке декоративны...   графика
# 1      Портрет женщины в шляпе с пером (фронтально, о...   графика
# 2      Три виньетки. Слева: овальная виньетка с цвето...   графика
# 3      Один под другим, в рамках: два женских портрет...   графика
# 4      В круге:  на фоне с цветочными узорами - поясн...   графика
# ...                                                  ...       ...
# 35702  Ахматова изображена по плечи, с поворотом слег...  живопись
# 35703  Городской пейзаж. На первом плане: справа руин...  живопись
# 35704  Абстрактная композиция состоящая из прямоуголь...  живопись
# 35705  В верхней части картины - летящий  влево желты...  живопись
# 35706  Абстрактно-предметная композиция. В центре изо...  живопись
#
#               author date_category  \
# 0            Малевич    1-я пол.20
# 1            Малевич    2-я пол.20
# 2            Малевич    1-я пол.20
# 3            Малевич    1-я пол.20
# 4            Малевич    2-я пол.20
# ...              ...           ...
# 35702  Петров-Водкин    1-я пол.20
# 35703         Павлов    1-я пол.20
# 35704         Волков    2-я пол.20
# 35705  Добротворский    2-я пол.20
# 35706        Белютин    2-я пол.20
#
#                                                key_words  \
# 0      мотив,декоративный,нанизанными,стержень,диск,ц...
# 1      младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2      виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3      изображенной,недлинный,распущенные,платье,женс...
# 4      круг,крапинка,вставка,цветочный,картон,портрет...
# ...                                                  ...
# 35702  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704  ленинский,овала,проспект,напоминать,цветной,со...
# 35705  расклешенной,планета,картина,парить,воздух,кра...
# 35706  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
#                                               embeddings  cluster
# 0      [0.58408934, 0.0099625345, 0.5078726, -0.09612...       18
# 1      [0.24424578, -0.07890896, 0.4376867, -0.012639...       14
# 2      [0.46791208, 0.33006114, 0.11194826, -0.200296...       15
# 3      [0.52606016, 0.16979823, 0.19851033, -0.142191...        6
# 4      [0.45312378, 0.23196974, 0.4026124, -0.0648039...       17
# ...                                                  ...      ...
# 35702  [0.29600233, 0.11324207, 0.48956913, -0.145708...       17
# 35703  [0.115966424, -0.49209934, 0.6091171, -0.14707...       11
# 35704  [0.31625056, 0.23952124, 0.15789297, -0.197009...       18
# 35705  [0.14807168, -0.113046505, 0.51217633, -0.1758...       18
# 35706  [0.09742064, 0.35496908, 0.73671126, 0.1387997...       18
#
# [35707 rows x 9 columns]

# %%
df['embeddings'] = df['embeddings'].apply(lambda x: x.tolist())

# %%
df_to_merge = pd.read_csv(folder_path + '/data_for_database.csv', sep=';', encoding='utf-8')

# %%
df_to_merge
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                                              description  \
# 0      В вертикальной прямоугольной рамке декоративны...
# 1      Портрет женщины в шляпе с пером (фронтально, о...
# 2      Три виньетки. Слева: овальная виньетка с цвето...
# 3      Один под другим, в рамках: два женских портрет...
# 4      В круге:  на фоне с цветочными узорами - поясн...
# ...                                                  ...
# 35702  Ахматова изображена по плечи, с поворотом слег...
# 35703  Городской пейзаж. На первом плане: справа руин...
# 35704  Абстрактная композиция состоящая из прямоуголь...
# 35705  В верхней части картины - летящий  влево желты...
# 35706  Абстрактно-предметная композиция. В центре изо...
#
#                                                image_url  catalog_num  \
# 0      http://goskatalog.ru/muzfo-imaginator/rest/ima...   10479770.0
# 1      http://goskatalog.ru/muzfo-imaginator/rest/ima...   10479769.0
# 2      http://goskatalog.ru/muzfo-imaginator/rest/ima...   10479768.0
# 3      http://goskatalog.ru/muzfo-imaginator/rest/ima...   10479767.0
# 4      http://goskatalog.ru/muzfo-imaginator/rest/ima...   10479766.0
# ...                                                  ...          ...
# 35702  http://goskatalog.ru/muzfo-imaginator/rest/ima...    9876002.0
# 35703  http://goskatalog.ru/muzfo-imaginator/rest/ima...    9876001.0
# 35704  http://goskatalog.ru/muzfo-imaginator/rest/ima...    9876000.0
# 35705  http://goskatalog.ru/muzfo-imaginator/rest/ima...    9875998.0
# 35706  http://goskatalog.ru/muzfo-imaginator/rest/ima...    9875996.0
#
#               registration_date  typology author_lastname author_name  \
# 0      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 1      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 2      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 3      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# 4      2018-01-31T12:54:54.729Z   графика         Малевич     Казимир
# ...                         ...       ...             ...         ...
# 35702  2017-12-11T11:44:01.596Z  живопись   Петров-Водкин      Кузьма
# 35703  2017-12-11T11:44:01.596Z  живопись          Павлов       Семен
# 35704  2017-12-11T11:44:01.596Z  живопись          Волков    Владимир
# 35705  2017-12-11T11:44:01.596Z  живопись   Добротворский      Сергей
# 35706  2017-12-11T11:44:01.596Z  живопись         Белютин        Элий
#
#       author_patronymic date_category  \
# 0           Северинович    1-я пол.20
# 1           Северинович    2-я пол.20
# 2           Северинович    1-я пол.20
# 3           Северинович    1-я пол.20
# 4           Северинович    2-я пол.20
# ...                 ...           ...
# 35702         Сергеевич    1-я пол.20
# 35703         Андреевич    1-я пол.20
# 35704          Петрович    2-я пол.20
# 35705        Николаевич    2-я пол.20
# 35706        Михайлович    2-я пол.20
#
#                                                key_words
# 0      мотив,декоративный,нанизанными,стержень,диск,ц...
# 1      младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2      виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3      изображенной,недлинный,распущенные,платье,женс...
# 4      круг,крапинка,вставка,цветочный,картон,портрет...
# ...                                                  ...
# 35702  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704  ленинский,овала,проспект,напоминать,цветной,со...
# 35705  расклешенной,планета,картина,парить,воздух,кра...
# 35706  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
# [35707 rows x 12 columns]

# %%
df['author'].rename('author_lastname')
df['author_name'] = df_to_merge['author_name']
df['author_patronymic'] = df_to_merge['author_patronymic']
df['catalog_num'] = df_to_merge['catalog_num']
df['registration_date'] = df_to_merge['registration_date']
df['image_url'] = df_to_merge['image_url']
df["registration_date"] = pd.to_datetime(df["registration_date"])
df
# Out:
#                                                    title  \
# 0                                    Декоративный мотив.
# 1      Женский портрет в шляпе с пером. На обороте: Н...
# 2                      Декоративные мотивы. Три виньетки
# 3                                  Два женских портрета.
# 4                           Женский портрет (погрудный).
# ...                                                  ...
# 35702                  Портрет Анны Андреевны Ахматовой.
# 35703                                              Зима.
# 35704                       Лестница. Ленинский проспект
# 35705                                       Без названия
# 35706                                            Завтрак
#
#                                                items  \
# 0                                       бумага, тушь
# 1             бумага, графитный карандаш, растушевка
# 2                           бумага верже, тушь, перо
# 3                             бумага, черные чернила
# 4      бумага, бумага цветная, тушь, гуашь, наклейка
# ...                                              ...
# 35702                                   холст, масло
# 35703                                   холст, масло
# 35704                                   холст, масло
# 35705                         холст на фанере, масло
# 35706                                   холст, масло
#
#                                              description  typology  \
# 0      В вертикальной прямоугольной рамке декоративны...   графика
# 1      Портрет женщины в шляпе с пером (фронтально, о...   графика
# 2      Три виньетки. Слева: овальная виньетка с цвето...   графика
# 3      Один под другим, в рамках: два женских портрет...   графика
# 4      В круге:  на фоне с цветочными узорами - поясн...   графика
# ...                                                  ...       ...
# 35702  Ахматова изображена по плечи, с поворотом слег...  живопись
# 35703  Городской пейзаж. На первом плане: справа руин...  живопись
# 35704  Абстрактная композиция состоящая из прямоуголь...  живопись
# 35705  В верхней части картины - летящий  влево желты...  живопись
# 35706  Абстрактно-предметная композиция. В центре изо...  живопись
#
#               author date_category  \
# 0            Малевич    1-я пол.20
# 1            Малевич    2-я пол.20
# 2            Малевич    1-я пол.20
# 3            Малевич    1-я пол.20
# 4            Малевич    2-я пол.20
# ...              ...           ...
# 35702  Петров-Водкин    1-я пол.20
# 35703         Павлов    1-я пол.20
# 35704         Волков    2-я пол.20
# 35705  Добротворский    2-я пол.20
# 35706        Белютин    2-я пол.20
#
#                                                key_words  \
# 0      мотив,декоративный,нанизанными,стержень,диск,ц...
# 1      младенец,оборот,шляпа,на,женщина,портрет,пером...
# 2      виньетка,прямоугольный,три,стеблями,рамка,симм...
# 3      изображенной,недлинный,распущенные,платье,женс...
# 4      круг,крапинка,вставка,цветочный,картон,портрет...
# ...                                                  ...
# 35702  ахматов,синий,подстричь,горбинка,андреевич,отл...
# 35703  дом,серый,полуразрушенные,разбитый,кирпичный,в...
# 35704  ленинский,овала,проспект,напоминать,цветной,со...
# 35705  расклешенной,планета,картина,парить,воздух,кра...
# 35706  абстрактно,предметный,прибор,завтрак,чайный,аб...
#
#                                               embeddings  cluster author_name  \
# 0      [0.5840893387794495, 0.00996253453195095, 0.50...       18     Казимир
# 1      [0.24424578249454498, -0.07890895754098892, 0....       14     Казимир
# 2      [0.46791207790374756, 0.330061137676239, 0.111...       15     Казимир
# 3      [0.526060163974762, 0.16979822516441345, 0.198...        6     Казимир
# 4      [0.4531237781047821, 0.23196974396705627, 0.40...       17     Казимир
# ...                                                  ...      ...         ...
# 35702  [0.2960023283958435, 0.11324206739664078, 0.48...       17      Кузьма
# 35703  [0.11596642434597015, -0.4920993447303772, 0.6...       11       Семен
# 35704  [0.3162505626678467, 0.23952123522758484, 0.15...       18    Владимир
# 35705  [0.14807167649269104, -0.11304650455713272, 0....       18      Сергей
# 35706  [0.09742064028978348, 0.3549690842628479, 0.73...       18        Элий
#
#       author_patronymic  catalog_num                registration_date  \
# 0           Северинович   10479770.0 2018-01-31 12:54:54.729000+00:00
# 1           Северинович   10479769.0 2018-01-31 12:54:54.729000+00:00
# 2           Северинович   10479768.0 2018-01-31 12:54:54.729000+00:00
# 3           Северинович   10479767.0 2018-01-31 12:54:54.729000+00:00
# 4           Северинович   10479766.0 2018-01-31 12:54:54.729000+00:00
# ...                 ...          ...                              ...
# 35702         Сергеевич    9876002.0 2017-12-11 11:44:01.596000+00:00
# 35703         Андреевич    9876001.0 2017-12-11 11:44:01.596000+00:00
# 35704          Петрович    9876000.0 2017-12-11 11:44:01.596000+00:00
# 35705        Николаевич    9875998.0 2017-12-11 11:44:01.596000+00:00
# 35706        Михайлович    9875996.0 2017-12-11 11:44:01.596000+00:00
#
#                                                image_url
# 0      http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 1      http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 2      http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 3      http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 4      http://goskatalog.ru/muzfo-imaginator/rest/ima...
# ...                                                  ...
# 35702  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35703  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35704  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35705  http://goskatalog.ru/muzfo-imaginator/rest/ima...
# 35706  http://goskatalog.ru/muzfo-imaginator/rest/ima...
#
# [35707 rows x 14 columns]

# %%
df.to_parquet(folder_path + '/data_for_database_final.parquet', index=False, engine="pyarrow")

# %%
df = pd.read_parquet(folder_path + '/data_for_database_final.parquet')

# %%
# !pip install python-dotenv sqlalchemy psycopg2
# Out:
# Requirement already satisfied: python-dotenv in c:\users\hedgehog\yandexdisk\projects\hackaton_1\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: sqlalchemy in c:\users\hedgehog\yandexdisk\projects\hackaton_1\.venv\lib\site-packages (2.0.37)
# Requirement already satisfied: psycopg2 in c:\users\hedgehog\yandexdisk\projects\hackaton_1\.venv\lib\site-packages (2.9.10)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hedgehog\yandexdisk\projects\hackaton_1\.venv\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\hedgehog\yandexdisk\projects\hackaton_1\.venv\lib\site-packages (from sqlalchemy) (4.12.2)
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
from sqlalchemy.orm import sessionmaker

# Загружаем переменные окружения из .env файла
load_dotenv()

# Получаем параметры из окружения
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')
db_user = os.getenv('DB_USERNAME')
db_password = os.getenv('DB_PASSWORD')

# Формируем строку подключения для PostgreSQL
DATABASE_URL = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

# Создание подключения к базе данных
engine = create_engine(DATABASE_URL)

# %%
engine.dispose()
engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)
session = Session()
session.rollback()

# %%
# Пример использования tqdm с to_sql
try:
    chunksize = 10  # Размер батча
    num_chunks = len(df) // chunksize + 1

    # Создаем прогресс-бар с tqdm
    with tqdm(total=num_chunks, desc="Загрузка в PostgreSQL") as pbar:
        for start in range(0, len(df), chunksize):
            df.iloc[start:start + chunksize].to_sql("images", engine, if_exists="append", index=False,
                                                    chunksize=chunksize)
            pbar.update(1)

    print("✅ Датасет загружен в PostgreSQL")
except Exception as e:
    session.rollback()
    print(f"❌ Ошибка: {e}")
finally:
    session.close()
# Out:
# Загрузка в PostgreSQL: 100%|██████████| 3571/3571 [22:32<00:00,  2.64it/s]
# ✅ Датасет загружен в PostgreSQL

# %%
def visualize_clusters(features, data, method="PCA"):
    # Снижение размерности
    if method == "PCA":
        reducer = PCA(n_components=2)
    elif method == "TSNE":
        reducer = TSNE(n_components=2, random_state=42, perplexity=30)
    else:
        raise ValueError("Метод должен быть 'PCA' или 'TSNE'")

    reduced_features = reducer.fit_transform(features)

    # Создание DataFrame для визуализации
    visualization_df = pd.DataFrame(reduced_features, columns=["Dim1", "Dim2"])
    visualization_df['cluster'] = data['cluster']

    # Визуализация кластеров
    plt.figure(figsize=(10, 8))
    sns.scatterplot(
        x="Dim1", y="Dim2",
        hue="cluster",
        palette="tab10",
        data=visualization_df,
        legend="full"
    )
    plt.title(f"Визуализация кластеров ({method})", fontsize=16)
    plt.xlabel("Первая компонента", fontsize=12)
    plt.ylabel("Вторая компонента", fontsize=12)
    plt.legend(title="Кластеры")
    plt.show()

# %%
# Визуализация кластеров с использованием PCA
visualize_clusters(embeddings, df, method="PCA")

# %%
# Визуализация кластеров с использованием t-SNE
visualize_clusters(embeddings, df, method="TSNE")

# %%
# Рекомендация экспонатов по кластеру
def recommend_by_cluster(query, data, kmeans_model, n_recommendations=5):
    # Получаем целевую размерность из KMeans
    target_dim = kmeans_model.cluster_centers_.shape[1]

    # Получаем эмбеддинг запроса
    query_embedding = get_embeddings([query]).numpy()

    # Приводим эмбеддинг к нужной размерности
    query_embedding_resized = resize_embedding(query_embedding, target_dim)

    # Определяем кластер для запроса
    query_cluster = kmeans_model.predict(query_embedding_resized)

    # Рекомендуем экспонаты из того же кластера
    recommended_items = data[data['cluster'] == query_cluster[0]].head(n_recommendations)
    return recommended_items

# %%
# Пример: Рекомендуем экспонаты для пользователя с запросом
user_query = "картина, изображающая пейзаж с озером"
recommended_items = recommend_by_cluster(user_query, df, kmeans_model)
recommended_items[['title', 'author', 'date_category']]
# Out:
#                                                   title   author date_category
# 1374                                             Закат.  Куинджи    1-я пол.20
# 1377         Миниатюра «Преподобный Корнилий Выговский»             Неизвестно
# 1397  Икона. Огненное восхождение пророка Илии, со с...             Неизвестно
# 1400           Икона. Усекновение главы Иоанна Предтечи             Неизвестно
# 1410       Икона. Архангел Михаил, святые Кирик и Улита             Неизвестно

# %% [markdown]
# ## Рекомендательная система на основе KMeans + KNN

# %%
def recommend_by_kmeans_knn(query, data, embeddings, kmeans_model, n_recommendations=5):
    # Получаем целевую размерность из KMeans
    target_dim = kmeans_model.cluster_centers_.shape[1]

    # Получаем эмбеддинг запроса
    query_embedding = get_embeddings([query]).numpy()

    # Приводим эмбеддинг к нужной размерности
    query_embedding_resized = resize_embedding(query_embedding, target_dim)

    # Определяем кластер для запроса
    query_cluster = kmeans_model.predict(query_embedding_resized)

    # Получаем индексы объектов в этом кластере
    cluster_indices = np.where(kmeans_model.labels_ == query_cluster)[0]

    # Если embeddings - разреженная матрица, конвертируем в плотный массив
    if isinstance(embeddings, np.ndarray):
        cluster_embeddings = embeddings[cluster_indices]
    else:
        cluster_embeddings = np.asarray(embeddings.todense()[cluster_indices])

    # Создаем модель NearestNeighbors
    nn_model = NearestNeighbors(n_neighbors=n_recommendations, metric='cosine')
    nn_model.fit(cluster_embeddings)

    # Находим ближайших соседей для запроса в этом кластере
    distances, indices = nn_model.kneighbors(query_embedding_resized)

    # Возвращаем рекомендованные объекты
    recommended_items = data.iloc[cluster_indices[indices.flatten()]]

    return recommended_items

# %%
# Пример: Рекомендуем экспонаты для пользователя с запросом
user_query = "картина, изображающая пейзаж с озером"

# Рекомендуем экспонаты, используя модель KMeans и KNN
recommended_items = recommend_by_kmeans_knn(user_query, df, embeddings, kmeans_model)

# Выводим рекомендованные экспонаты с нужными колонками
recommended_items[['title', 'author', 'date_category']]
# Out:
#                                                    title   author  \
# 1374                                              Закат.  Куинджи
# 30318  Заготовка для подокладной иконы "Христос Вседе...
# 28205          "Наши казаки в гостях у турецкого мушира"
# 28206  "Генерал лейтенант князь Василий Осипович Бебу...
# 28207                                        "Николай I"
#
#       date_category
# 1374     1-я пол.20
# 30318    1-я пол.20
# 28205    2-я пол.19
# 28206    2-я пол.19
# 28207    2-я пол.19

# %% [markdown]
# # Функции для чат-бота

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from transformers import BertTokenizer, BertModel
import torch
import os
import joblib  # Для загрузки k-means модели

# %%
file_model_2 = '/content/drive/MyDrive/data/Hackaton/Вариант 2/kmeans_model.joblib'
file_data_2 = '/content/drive/MyDrive/data/Hackaton/Вариант 2/data_for_database_final.parquet'

# %%
# === Загрузка модели KMeans ===

kmeans_model = joblib.load(file_model_2)

# === Загрузка модели RuBERT ===
model_name = 'DeepPavlov/rubert-base-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
model.eval()  # Переключаем в режим инференса

# === Загрузка эмбеддингов из parquet ===
df = pd.read_parquet(file_data_2)
df["id"] = df.index

# Преобразуем эмбеддинги в numpy-массив
embeddings = np.vstack(df["embeddings"].apply(np.array))  # Если хранятся как списки


# === Функция для получения эмбеддингов запроса ===
def get_embeddings(query):
    inputs = tokenizer(query, padding=True, truncation=True, return_tensors="pt", max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1)  # Усредняем по нужной размерности
    return embeddings.cpu().numpy()  # Переводим в numpy


# === Функция рекомендаций через KMeans + KNN ===
def recommend_by_kmeans_knn(query, embeddings, kmeans_model, n_recommendations=5):
    query_embedding = get_embeddings(query)  # Уже numpy
    query_cluster = kmeans_model.predict(query_embedding)[0]  # Получаем кластер
    cluster_indices = np.where(kmeans_model.labels_ == query_cluster)[0]  # Выбираем объекты из кластера

    cluster_embeddings = embeddings[cluster_indices]  # Берем их эмбеддинги

    # Создаем KNN-модель
    nn_model = NearestNeighbors(n_neighbors=n_recommendations, metric='cosine')
    nn_model.fit(cluster_embeddings)

    distances, indices = nn_model.kneighbors(query_embedding)

    recommended_indices = cluster_indices[indices.flatten()]  # Переводим в индексы исходного массива
    return recommended_indices


# === Функция получения экспонатов по индексам ===
def get_exhibits_by_indices(indices):
    return df.iloc[indices][["id", "title", "author", "date_category"]].to_dict(orient="records")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %%
# === Пример использования ===
# user_query = "Персик девочка стол окно цветы сирень"
user_query = "лунный,бухта,морской,луна,ночь,берег,набережнная"
recommended_indices = recommend_by_kmeans_knn(user_query, embeddings, kmeans_model)

# Получаем рекомендованные экспонаты
recommended_exhibits = get_exhibits_by_indices(recommended_indices)

for exhibit in recommended_exhibits:
    print(exhibit)
# Out:
# {'id': 32288, 'title': 'Вид города Одессы.', 'author': 'Айвазовский', 'date_category': '1-я пол.19'}
# {'id': 14960, 'title': 'Морской пейзаж', 'author': 'Бурлюк', 'date_category': '1-я пол.20'}
# {'id': 25960, 'title': 'Берег моря', 'author': 'Боткин', 'date_category': '2-я пол.19'}
# {'id': 32301, 'title': 'Морской пролив с маяком.', 'author': 'Айвазовский', 'date_category': '1-я пол.19'}
# {'id': 13401, 'title': 'На реке Мойке вечером', 'author': 'Платунов', 'date_category': '1-я пол.20'}
